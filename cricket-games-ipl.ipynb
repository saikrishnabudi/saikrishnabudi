# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/cricket-matches-analysis/matches.csv
# /kaggle/input/cricket-games/matches.csv

# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %%
## Here we take the dataset "Matches.csv" and dropped in the name 'df'.
## If we print the df then we got the whole dataset.

df=pd.read_csv("/kaggle/input/cricket-games/matches.csv")
print(df)
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
## Here 'df.head()' belongs to R language
## Here 'df.head()' means it will shows us the only top five data
## if we specify any number in 'df.head()' it will shows the until the value which we have given the before in the 'df.head() function'

df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
## Here 'df.tail()' means it will shows us the bottom five data.

df.tail()
# Out:
#         id  season           city        date                  team1  \
# 750  11346    2019         Mohali  05-05-2019    Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
#
#                    team2          toss_winner toss_decision  result  \
# 750      Kings XI Punjab      Kings XI Punjab         field  normal
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 750           0      Kings XI Punjab            0               6
# ...

# %%
## Example

df.head(8)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8    2017     Indore  10-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
##Example

df.tail(8)
# Out:
#         id  season           city        date                  team1  \
# 747  11343    2019         Mohali  03-05-2019        Kings XI Punjab
# 748  11344    2019          Delhi  04-05-2019       Rajasthan Royals
# 749  11345    2019      Bengaluru  04-05-2019    Sunrisers Hyderabad
# 750  11346    2019         Mohali  05-05-2019    Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 747        Kolkata Knight Riders        Kolkata Knight Riders         field
# 748               Delhi Capitals             Rajasthan Royals           bat
# 749  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
## Here this will shows us only columns names.

df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
## Here 'data' is column name and we can put the data into the variable name 

data=df.columns
print(data)
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
## Here it will shows us the whole info about the data 

df.shape
# Out:
# (755, 18)

# %%
## This is called Accessing the columns and we can access the col whatever we want in the dataset. 

df["toss_winner"]
# Out:
# 0      Royal Challengers Bangalore
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 750                Kings XI Punjab
# 751                 Mumbai Indians
# 752            Chennai Super Kings
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# Name: toss_winner, Length: 755, dtype: object

# %%
## Example

df[["season","city","venue","winner"]]
# Out:
#      season           city                                      venue  \
# 0      2017      Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 1      2017           Pune    Maharashtra Cricket Association Stadium
# 2      2017         Rajkot     Saurashtra Cricket Association Stadium
# 3      2017         Indore                     Holkar Cricket Stadium
# 4      2017      Bangalore                      M Chinnaswamy Stadium
# ..      ...            ...                                        ...
# 750    2019         Mohali                          IS Bindra Stadium
# 751    2019         Mumbai                           Wankhede Stadium
# 752    2019        Chennai                  M. A. Chidambaram Stadium
# 753    2019  Visakhapatnam                           ACA-VDCA Stadium
# 754    2019  Visakhapatnam                           ACA-VDCA Stadium
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# ...

# %%
##Getting the records from the dataset where the teams win the match with more than five wickets. 

df[df["win_by_wickets"]>5]
# Out:
#         id  season           city        date                        team1  \
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 5        6    2017      Hyderabad  09-04-2017                Gujarat Lions
# 7        8    2017         Indore  10-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 747  11343    2019         Mohali  03-05-2019              Kings XI Punjab
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
##Getting the records from the dataset where the teams win the match with more than ten runs. 


df[df["win_by_runs"]>10]
# Out:
#         id  season       city        date                        team1  \
# 0        1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9    2017       Pune  11-04-2017             Delhi Daredevils
# 13      14    2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15    2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...     ...        ...         ...                          ...
# 739  11335    2019    Chennai  26-04-2019               Mumbai Indians
# 741  11337    2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338    2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339    2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341    2019    Chennai  01-05-2019          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
## This will shows us the where the match season is Lessthan '2009' 

df[df["season"]<2009]
# Out:
#       id  season        city        date                        team1  \
# 59    60    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 60    61    2008  Chandigarh  19-04-2008          Chennai Super Kings
# 61    62    2008       Delhi  19-04-2008             Rajasthan Royals
# 62    63    2008      Mumbai  20-04-2008               Mumbai Indians
# 63    64    2008     Kolkata  20-04-2008              Deccan Chargers
# 64    65    2008      Jaipur  21-04-2008              Kings XI Punjab
# 65    66    2008   Hyderabad  22-04-2008              Deccan Chargers
# 66    67    2008     Chennai  23-04-2008          Chennai Super Kings
# 67    68    2008   Hyderabad  24-04-2008              Deccan Chargers
# 68    69    2008  Chandigarh  25-04-2008              Kings XI Punjab
# 69    70    2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 70    71    2008     Chennai  26-04-2008        Kolkata Knight Riders
# ...

# %%
df[df["season"]>2018]
# Out:
#         id  season           city        date                        team1  \
# 696  11137    2019        Chennai  23-03-2019  Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24-03-2019          Sunrisers Hyderabad
# 698  11139    2019         Mumbai  24-03-2019               Delhi Capitals
# 699  11140    2019         Jaipur  25-03-2019              Kings XI Punjab
# 700  11141    2019          Delhi  26-03-2019               Delhi Capitals
# 701  11142    2019        Kolkata  27-03-2019        Kolkata Knight Riders
# 702  11143    2019      Bengaluru  28-03-2019               Mumbai Indians
# 703  11144    2019      Hyderabad  29-03-2019             Rajasthan Royals
# 704  11145    2019         Mohali  30-03-2019               Mumbai Indians
# 705  11146    2019          Delhi  30-03-2019        Kolkata Knight Riders
# 706  11147    2019      Hyderabad  31-03-2019          Sunrisers Hyderabad
# ...

# %%
df[["team1","team2"]][df["win_by_runs"]>20]
# Out:
#                            team1                        team2
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 8               Delhi Daredevils       Rising Pune Supergiant
# 14              Delhi Daredevils              Kings XI Punjab
# 16        Rising Pune Supergiant  Royal Challengers Bangalore
# 19   Royal Challengers Bangalore                Gujarat Lions
# ..                           ...                          ...
# 729               Mumbai Indians               Delhi Capitals
# 739               Mumbai Indians          Chennai Super Kings
# 742        Kolkata Knight Riders               Mumbai Indians
# 743          Sunrisers Hyderabad              Kings XI Punjab
# 745          Chennai Super Kings               Delhi Capitals
#
# [177 rows x 2 columns]

# %%
df[["team1","team2"]][df["win_by_wickets"]>5]
# Out:
#                            team1                   team2
# 1                 Mumbai Indians  Rising Pune Supergiant
# 2                  Gujarat Lions   Kolkata Knight Riders
# 3         Rising Pune Supergiant         Kings XI Punjab
# 5                  Gujarat Lions     Sunrisers Hyderabad
# 7    Royal Challengers Bangalore         Kings XI Punjab
# ..                           ...                     ...
# 747              Kings XI Punjab   Kolkata Knight Riders
# 750          Chennai Super Kings         Kings XI Punjab
# 751        Kolkata Knight Riders          Mumbai Indians
# 752          Chennai Super Kings          Mumbai Indians
# 754               Delhi Capitals     Chennai Super Kings
#
# [267 rows x 2 columns]

# %%
df[["season","team1","team2"]][df["win_by_runs"]>145]
# Out:
#     season           team1             team2
# 43    2017  Mumbai Indians  Delhi Daredevils

# %%
df[["season","team1","winner"]][(df["team1"]=="Chennai Super Kings") & (df["team2"]=="Delhi Daredevils")]
# Out:
#      season                team1               winner
# 78     2008  Chennai Super Kings     Delhi Daredevils
# 140    2009  Chennai Super Kings  Chennai Super Kings
# 223    2010  Chennai Super Kings     Delhi Daredevils
# 288    2011  Chennai Super Kings  Chennai Super Kings
# 317    2012  Chennai Super Kings     Delhi Daredevils
# 379    2012  Chennai Super Kings  Chennai Super Kings
# 403    2013  Chennai Super Kings  Chennai Super Kings
# 445    2013  Chennai Super Kings  Chennai Super Kings
# 464    2014  Chennai Super Kings  Chennai Super Kings
# 518    2015  Chennai Super Kings  Chennai Super Kings
# 564    2015  Chennai Super Kings     Delhi Daredevils
# 665    2018  Chennai Super Kings  Chennai Super Kings

# %%
df[["season","team1","toss_decision"]][(df["team1"]=="Chennai Super Kings") & (df["city"]=="Chennai")]
# Out:
#      season                team1 toss_decision
# 66     2008  Chennai Super Kings         field
# 78     2008  Chennai Super Kings           bat
# 84     2008  Chennai Super Kings         field
# 90     2008  Chennai Super Kings         field
# 205    2010  Chennai Super Kings           bat
# 210    2010  Chennai Super Kings           bat
# 223    2010  Chennai Super Kings           bat
# 234    2011  Chennai Super Kings           bat
# 247    2011  Chennai Super Kings           bat
# 261    2011  Chennai Super Kings         field
# 271    2011  Chennai Super Kings           bat
# 288    2011  Chennai Super Kings           bat
# 296    2011  Chennai Super Kings           bat
# 306    2011  Chennai Super Kings           bat
# 307    2012  Chennai Super Kings         field
# 331    2012  Chennai Super Kings         field
# 346    2012  Chennai Super Kings           bat
# 351    2012  Chennai Super Kings           bat
# 379    2012  Chennai Super Kings         field
# ...

# %%
## Maximum value 

df["win_by_runs"].max()
# Out:
# 146

# %%
## Minimum Value

df["win_by_runs"].min()
# Out:
# 0

# %%
## Mean Value

df["win_by_runs"].mean()
# Out:
# 13.29933774834437

# %%
## Median Value

df["win_by_runs"].median()
# Out:
# 0.0

# %%
## Mode Value 

df["win_by_runs"].mode()
# Out:
# 0    0
# Name: win_by_runs, dtype: int64

# %%
## Variable Value

df["win_by_runs"].var()
# Out:
# 551.4248669348464

# %%
## Standard Deviation Value

df["win_by_runs"].std()
# Out:
# 23.48243741469029

# %%
## Round Function 
## In Mean we got the large Decimal value. Incase we filter that large decimal to small decimal we use the Round Function.


round(df["win_by_runs"].mean(),4)
# Out:
# 13.2993

# %%
df["team1"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
## Unique value occurences


df["player_of_match"].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
# '[:5]' it means it will shows us the only top five players
df["player_of_match"].value_counts() [:6]
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# Name: count, dtype: int64

# %%
# '[5:]' Here it will shows us the after top five players

df["player_of_match"].value_counts() [5:]
# Out:
# player_of_match
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 221, dtype: int64

# %%
df["season"].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019])

# %%
df["team1"].value_counts() [:5]
# Out:
# team1
# Mumbai Indians                 100
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Name: count, dtype: int64

# %%
df["team2"].value_counts()
# Out:
# team2
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            74
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: count, dtype: int64

# %%
df["win_by_runs"].value_counts()
# Out:
# win_by_runs
# 0      419
# 14      13
# 4       11
# 10      11
# 13       9
#       ...
# 76       1
# 111      1
# 74       1
# 42       1
# 118      1
# Name: count, Length: 89, dtype: int64

# %%
len(df["venue"].value_counts())
# Out:
# 41

# %%
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    755.000000   755.000000  755.000000   755.000000      755.000000
# mean    1779.433113  2013.437086    0.025166    13.299338        3.354967
# std     3448.993305     3.363039    0.156732    23.482437        3.388009
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.500000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.000000  2013.000000    0.000000     0.000000        4.000000
# 75%      566.500000  2016.000000    0.000000    19.000000        6.000000
# max    11414.000000  2019.000000    1.000000   146.000000       10.000000

# %%
## Index based slicing

df.iloc[10:40,2:6]
# Out:
#           city        date                        team1  \
# 10     Kolkata  13-04-2017              Kings XI Punjab
# 11   Bangalore  14-04-2017  Royal Challengers Bangalore
# 12      Rajkot  14-04-2017       Rising Pune Supergiant
# 13     Kolkata  15-04-2017        Kolkata Knight Riders
# 14       Delhi  15-04-2017             Delhi Daredevils
# 15      Mumbai  16-04-2017                Gujarat Lions
# 16   Bangalore  16-04-2017       Rising Pune Supergiant
# 17       Delhi  17-04-2017             Delhi Daredevils
# 18   Hyderabad  17-04-2017          Sunrisers Hyderabad
# 19      Rajkot  18-04-2017  Royal Challengers Bangalore
# 20   Hyderabad  19-04-2017          Sunrisers Hyderabad
# 21      Indore  20-04-2017              Kings XI Punjab
# 22     Kolkata  21-04-2017        Kolkata Knight Riders
# 23      Mumbai  22-04-2017               Mumbai Indians
# 24        Pune  22-04-2017          Sunrisers Hyderabad
# 25      Rajkot  23-04-2017              Kings XI Punjab
# ...

# %%
#location based slicing

df.loc[20:40,["team1","team2"]]
# Out:
#                           team1                        team2
# 20          Sunrisers Hyderabad             Delhi Daredevils
# 21              Kings XI Punjab               Mumbai Indians
# 22        Kolkata Knight Riders                Gujarat Lions
# 23               Mumbai Indians             Delhi Daredevils
# 24          Sunrisers Hyderabad       Rising Pune Supergiant
# 25              Kings XI Punjab                Gujarat Lions
# 26        Kolkata Knight Riders  Royal Challengers Bangalore
# 27       Rising Pune Supergiant               Mumbai Indians
# 28       Rising Pune Supergiant        Kolkata Knight Riders
# 29  Royal Challengers Bangalore                Gujarat Lions
# 30             Delhi Daredevils        Kolkata Knight Riders
# 31          Sunrisers Hyderabad              Kings XI Punjab
# 32       Rising Pune Supergiant  Royal Challengers Bangalore
# 33                Gujarat Lions               Mumbai Indians
# ...

# %%
# Length of dataset

len(df)
# Out:
# 755

# %%
len(df.loc[20:40,["team1","team2"]])
# Out:
# 21

# %%
## Drop-Here i dropped the 'season' column using the 'axis=1'
## we can use the 'axis=0' for dropping the Row

df.drop("season",axis=1)
# Out:
#         id           city        date                        team1  \
# 0        1      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2           Pune  06-04-2017               Mumbai Indians
# 2        3         Rajkot  07-04-2017                Gujarat Lions
# 3        4         Indore  08-04-2017       Rising Pune Supergiant
# 4        5      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...            ...         ...                          ...
# 750  11346         Mohali  05-05-2019          Chennai Super Kings
# 751  11347         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  Visakhapatnam  10-05-2019               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df.drop(['umpire1'], axis=1)
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
df.dropna(axis=0)
# Out:
#         id  season           city        date                        team1  \
# 636   7894    2018         Mumbai  07-04-2018               Mumbai Indians
# 637   7895    2018         Mohali  08-04-2018             Delhi Daredevils
# 638   7896    2018        Kolkata  08-04-2018  Royal Challengers Bangalore
# 639   7897    2018      Hyderabad  09-04-2018             Rajasthan Royals
# 640   7898    2018        Chennai  10-04-2018        Kolkata Knight Riders
# ..     ...     ...            ...         ...                          ...
# 749  11345    2019      Bengaluru  04-05-2019          Sunrisers Hyderabad
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
## isna(): Checks for missing values

df.isna()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 750  False   False  False  False  False  False        False          False
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
#
# ...

# %%
## Column wise count of missing values

df.isna().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
## Drop Duplicates

df.drop_duplicates(inplace=True)
print(df)
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 750  11346    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
## sort the values

df.sort_values("season",ascending=True)
# Out:
#         id  season           city        date                        team1  \
# 116    117    2008         Mumbai  01-06-2008          Chennai Super Kings
# 82      83    2008         Jaipur  04-05-2008          Chennai Super Kings
# 81      82    2008         Mumbai  04-05-2008               Mumbai Indians
# 80      81    2008     Chandigarh  03-05-2008              Kings XI Punjab
# 79      80    2008      Hyderabad  25-05-2008              Deccan Chargers
# ..     ...     ...            ...         ...                          ...
# 720  11316    2019         Jaipur  11-04-2019             Rajasthan Royals
# 721  11317    2019        Kolkata  12-04-2019        Kolkata Knight Riders
# 722  11318    2019         Mumbai  13-04-2019               Mumbai Indians
# 709  11150    2019         Jaipur  02-04-2019  Royal Challengers Bangalore
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
#
# ...

# %%
df.sort_values("season",ascending=False)
# Out:
#         id  season           city        date                  team1  \
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 725  11321    2019      Hyderabad  14-04-2019         Delhi Capitals
# 723  11319    2019         Mohali  13-04-2019        Kings XI Punjab
# 722  11318    2019         Mumbai  13-04-2019         Mumbai Indians
# 721  11317    2019        Kolkata  12-04-2019  Kolkata Knight Riders
# ..     ...     ...            ...         ...                    ...
# 85      86    2008         Mumbai  07-05-2008       Rajasthan Royals
# 86      87    2008          Delhi  08-05-2008       Delhi Daredevils
# 87      88    2008        Kolkata  08-05-2008  Kolkata Knight Riders
# 88      89    2008         Jaipur  09-05-2008        Deccan Chargers
# 72      73    2008     Chandigarh  27-04-2008       Delhi Daredevils
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df["win_by_runs"].sort_values()
# Out:
# 754      0
# 360      0
# 359      0
# 632      0
# 357      0
#       ...
# 410    130
# 556    138
# 59     140
# 619    144
# 43     146
# Name: win_by_runs, Length: 755, dtype: int64

# %%
# grouping based on specific categories

df.groupby("team1")["win_by_runs"].mean()
# Out:
# team1
# Chennai Super Kings            20.056180
# Deccan Chargers                 9.790698
# Delhi Capitals                 15.333333
# Delhi Daredevils                9.722222
# Gujarat Lions                   0.071429
# Kings XI Punjab                10.219780
# Kochi Tuskers Kerala            3.285714
# Kolkata Knight Riders          12.867470
# Mumbai Indians                 18.650000
# Pune Warriors                   6.950000
# Rajasthan Royals               13.358209
# Rising Pune Supergiant         15.375000
# Rising Pune Supergiants         0.000000
# Royal Challengers Bangalore    14.729412
# Sunrisers Hyderabad            11.857143
# Name: win_by_runs, dtype: float64

# %%
df.groupby("team2")["win_by_wickets"].mean()
# Out:
# team2
# Chennai Super Kings            3.905405
# Deccan Chargers                2.250000
# Delhi Capitals                 2.900000
# Delhi Daredevils               3.089888
# Gujarat Lions                  4.062500
# Kings XI Punjab                3.152941
# Kochi Tuskers Kerala           4.285714
# Kolkata Knight Riders          3.694737
# Mumbai Indians                 3.569767
# Pune Warriors                  1.384615
# Rajasthan Royals               3.412500
# Rising Pune Supergiant         3.875000
# Rising Pune Supergiants        2.857143
# Royal Challengers Bangalore    3.305263
# Sunrisers Hyderabad            3.844444
# Name: win_by_wickets, dtype: float64

# %%
df.groupby(["team1","season"])["win_by_wickets"].mean()
# Out:
# team1                season
# Chennai Super Kings  2008      3.888889
#                      2009      2.100000
#                      2010      2.125000
#                      2011      1.750000
#                      2012      3.416667
#                                  ...
# Sunrisers Hyderabad  2015      2.333333
#                      2016      2.333333
#                      2017      2.555556
#                      2018      2.555556
#                      2019      3.875000
# Name: win_by_wickets, Length: 100, dtype: float64

# %%
df1=df.groupby(["team1","season"])["win_by_wickets"].mean()
print(df1)
# Out:
# team1                season
# Chennai Super Kings  2008      3.888889
#                      2009      2.100000
#                      2010      2.125000
#                      2011      1.750000
#                      2012      3.416667
#                                  ...
# Sunrisers Hyderabad  2015      2.333333
#                      2016      2.333333
#                      2017      2.555556
#                      2018      2.555556
#                      2019      3.875000
# Name: win_by_wickets, Length: 100, dtype: float64

# %%
df1=df1.reset_index()
print(df1)
# Out:
#                   team1  season  win_by_wickets
# 0   Chennai Super Kings    2008        3.888889
# 1   Chennai Super Kings    2009        2.100000
# 2   Chennai Super Kings    2010        2.125000
# 3   Chennai Super Kings    2011        1.750000
# 4   Chennai Super Kings    2012        3.416667
# ..                  ...     ...             ...
# 95  Sunrisers Hyderabad    2015        2.333333
# 96  Sunrisers Hyderabad    2016        2.333333
# 97  Sunrisers Hyderabad    2017        2.555556
# 98  Sunrisers Hyderabad    2018        2.555556
# 99  Sunrisers Hyderabad    2019        3.875000
#
# [100 rows x 3 columns]

# %%
df.groupby(["team1","season"])["win_by_wickets"].std()
# Out:
# team1                season
# Chennai Super Kings  2008      4.044887
#                      2009      2.998148
#                      2010      2.948971
#                      2011      3.194455
#                      2012      3.396745
#                                  ...
# Sunrisers Hyderabad  2015      3.605551
#                      2016      3.535534
#                      2017      3.126944
#                      2018      3.503966
#                      2019      2.850439
# Name: win_by_wickets, Length: 100, dtype: float64

# %%
## MATPLOT Lib

import matplotlib.pyplot as plt

# %%
##Boxplot

plt.boxplot(df["season"])
plt.xlabel("Indian Premier League")
plt.ylabel("Ipl Seasons")
plt.show()

# %%
## Scatterplot

plt.scatter(df["win_by_wickets"],df["win_by_runs"])
plt.xlabel("Win by wickets")
plt.ylabel("Win ny runs")
plt.show()

# %%
## Histplot

plt.hist(df["win_by_wickets"])
plt.xlabel("wickets won")
# Out:
# Text(0.5, 0, 'wickets won')

# %%
import seaborn as sns

# %%
## Histplot

sns.histplot(df["win_by_runs"])
# Out:
# <Axes: xlabel='win_by_runs', ylabel='Count'>

# %%
sns.histplot(df["win_by_runs"],kde=True)
# Out:
# <Axes: xlabel='win_by_runs', ylabel='Count'>

# %%
sns.histplot(df["win_by_wickets"],kde=True)
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='Count'>

# %%
## Dist Plot

sns.distplot(df["win_by_wickets"])

import warnings
warnings.filterwarnings("ignore")
# Out:
# /tmp/ipykernel_20/227261790.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["win_by_wickets"])

# %%
## Countplot

sns.countplot(x="win_by_wickets",data=df)
# Out:
# <Axes: xlabel='win_by_wickets', ylabel='count'>

# %%
sns.countplot(x="season",data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df["season"].value_counts()
# Out:
# season
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2017    59
# 2015    59
# 2019    59
# 2008    58
# 2009    57
# Name: count, dtype: int64

# %%
sns.scatterplot(x="win_by_runs",y="win_by_wickets",data=df)
# Out:
# <Axes: xlabel='win_by_runs', ylabel='win_by_wickets'>

# %%
sns.scatterplot(x="season",y="win_by_wickets",hue="win_by_runs",data=df)
# Out:
# <Axes: xlabel='season', ylabel='win_by_wickets'>

# %%
sns.pairplot(df[["id","season","city","date","team1","team2","toss_winner","toss_decision","result","dl_applied","winner","win_by_runs","win_by_wickets","player_of_match","venue","umpire1","umpire2","umpire3"]])
plt.show()

# %%
# Selecting only numeric columns for correlation analysis
numeric_data = df.select_dtypes(include=['int64', 'float64'])

# Correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
